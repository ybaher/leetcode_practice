# %%
def isPalindrome(x):
    """
    :type x: int
    :rtype: bool
    """
    x = str(x)
    return x == x[::-1]

isPalindrome(121)
# Out:
# True

# %%
def romanToInt(s):
    """
    :type s: str
    :rtype: int
    """
    roman_values = {
    "I": 1,
    "V": 5,
    "X": 10,
    "L": 50,
    "C": 100,
    "D": 500,
    "M": 1000}

    value = 0

    for i in range(len(s)):
        current = roman_values[s[i]]

        if i + 1 < len(s) and current < roman_values[s[i + 1]]:
            value -= current

        else:
            value += current

    return value
                

s = "LVIII"
romanToInt(s)
# Out:
# 58

# %%
def longestCommonPrefix(strs):
    """
    :type strs: List[str]
    :rtype: str
    """
    stack = []
    length = len(strs) - 1

strs = ["flower","flow","flight"]
longestCommonPrefix(strs)
# Out:
# f
# l
# o
# w
# e
# r
# f
# l
# o
# w
# f
# l
# i
# g
# h
# t

# %%
class Solution(object):
    def isValid(self, s):
        """
        :type s: str
        :rtype: bool
        """
        stack = []

        for i in s:
            if i == '{' or i == '(' or i == '[':
                stack.append(i)

            elif i == '}':
                if len(stack) == 0 or stack[-1] != '{':
                    return False
                stack.pop() 

            elif i == ']':
                if len(stack) == 0 or stack[-1] != '[':
                    return False
                stack.pop()
                
            elif i == ')':
                if len(stack) == 0 or stack[-1] != '(':
                    return False
                stack.pop() 
                
        return len(stack) == 0
# Out:
# True

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %%
def twoSum(nums, target):
    for i in range(len(nums)):
        for j in range(i + 1, len(nums)):
            if nums[i] + nums[j] == target:
                return (i, j)

nums = [2,7,11,15]
target = 9
twoSum(nums, target)
# Out:
# (0, 1)

# %%
def isPalindrome(x):
    """
    :type x: int
    :rtype: bool
    """
    return str(x) == str(x)[::-1]


x = 121
isPalindrome(x)
# Out:
# True

# %%
def romanToInt(s):
    """
    :type s: str
    :rtype: int
    """
    total = 0
    roman = {
    "I": 1,
    "V": 5,
    "X": 10,
    "L": 50,
    "C": 100,
    "D": 500,
    "M": 1000}

    for i in range(len(s)):
        if i + 1 < len(s) and roman[s[i]] < roman[s[i + 1]]:
            total -= roman[s[i]]
        else:
            total += roman[s[i]]
            
    return total

s = "MCMXCIV"
romanToInt(s)
# Out:
# 1994

# %% [markdown]
# if current_value < next_value: <br>
#     total -= current_value <br>
# else:<br>
#     total += current_value

# %%
def longestCommonPrefix(strs):
    prefix = ""

    for i in range(len(strs[0])):
        current_character = strs[0][i]

        for j in range(1, len(strs)):
            if i >= len(strs[j]) or strs[j][i] != current_character:
                return prefix

        prefix += current_character

    return prefix


strs = ["flower", "flow", "flight"]
print(longestCommonPrefix(strs))
# Out:
# fl
